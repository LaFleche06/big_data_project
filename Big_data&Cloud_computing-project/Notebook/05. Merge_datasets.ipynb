# %% [markdown]
# # Introduction
#
#  Ici on va meregr les bases selon les besoins d'analyses et en fonction des données disponibles.
#  On aura une base globale mensuelle et une base globale annuelle

# %%
# Bibliothèques nécessaires
from pyspark.sql import functions as F

# %%
# On va d'abord créer la base annuelle. Pour cela, on va chargée nos données météorologiques qu'on va merger aux données économiques traitées dans le notebook 03. data_clean_economic

df_weather = spark.read.table("weather_senegal_clean")
df_weather.printSchema()
display(df_weather.limit(5))
# Out:
# root
#  |-- region: string (nullable = true)
#  |-- time: timestamp (nullable = true)
#  |-- tavg: double (nullable = true)
#  |-- tmin: double (nullable = true)
#  |-- tmax: double (nullable = true)
#  |-- prcp: double (nullable = true)
#  |-- wspd: double (nullable = true)
#  |-- pres: double (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>time</th><th>tavg</th><th>tmin</th><th>tmax</th><th>prcp</th><th>wspd</th><th>pres</th></tr></thead><tbody><tr><td>Dakar</td><td>2005-01-01T00:00:00.000Z</td><td>22.6</td><td>18.5</td><td>28.0</td><td>0.0</td><td>16.4</td><td>1012.2986111111122</td></tr><tr><td>Dakar</td><td>2005-01-02T00:00:00.000Z</td><td>21.5</td><td>18.8</td><td>24.0</td><td>0.0</td><td>17.0</td><td>1012.2986111111122</td></tr><tr><td>Dakar</td><td>2005-01-05T00:00:00.000Z</td><td>20.1</td><td>18.0</td><td>23.0</td><td>0.0</td><td>16.2</td><td>1012.2986111111122</td></tr><tr><td>Dakar</td><td>2005-01-08T00:00:00.000Z</td><td>22.1</td><td>19.9</td><td>25.0</td><td>0.0</td><td>21.2</td><td>1012.2986111111122</td></tr><tr><td>Dakar</td><td>2005-01-09T00:00:00.000Z</td><td>21.6</td><td>19.0</td><td>25.0</td><td>0.0</td><td>19.0</td><td>1012.2986111111122</td></tr></tbody></table></div>

# %%
# On crée une variable date 
df_weather = df_weather.withColumn(
    "Year",
    F.year(F.col("time"))
)

# %%
# On agrège les données pour qu'elles soient annuelles. On va travailler ici avec les température moyennes, précipitations et pressions.
df_weather_annual = (
    df_weather
    .groupBy("Year")
    .agg(
        F.avg("tavg").alias("avg_temperature"),
        F.sum("prcp").alias("total_precipitation"),
        F.avg("pres").alias("avg_pressure")
    )
)

# %%
# Affichons la base
display(df_weather_annual.orderBy("Year"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>avg_temperature</th><th>total_precipitation</th><th>avg_pressure</th></tr></thead><tbody><tr><td>2005</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2006</td><td>28.531488203266775</td><td>3399.0999999999995</td><td>1011.2394931916094</td></tr><tr><td>2007</td><td>28.177815699658694</td><td>1702.0</td><td>1011.4508161488728</td></tr><tr><td>2008</td><td>27.88793407886991</td><td>3991.7000000000007</td><td>1011.3557871285636</td></tr><tr><td>2009</td><td>27.9764381402679</td><td>4925.600000000004</td><td>1011.1819275281549</td></tr><tr><td>2010</td><td>28.764912280701715</td><td>5289.700000000004</td><td>1011.2049353344339</td></tr><tr><td>2011</td><td>27.861874386653625</td><td>3783.8000000000006</td><td>1011.29236549284</td></tr><tr><td>2012</td><td>27.986167146974044</td><td>6735.300000000003</td><td>1011.2694924187703</td></tr><tr><td>2013</td><td>28.079271991911074</td><td>4491.799999999997</td><td>1011.2964570549655</td></tr><tr><td>2014</td><td>27.59651545036165</td><td>3139.8000000000006</td><td>1011.414740059626</td></tr><tr><td>2015</td><td>27.827017744705202</td><td>4602.000000000003</td><td>1011.54409192467</td></tr><tr><td>2016</td><td>28.28251915708813</td><td>3514.100000000001</td><td>1011.4944817978778</td></tr><tr><td>2017</td><td>28.530430327868874</td><td>3453.0</td><td>1011.2937445523148</td></tr><tr><td>2018</td><td>27.761712668082044</td><td>3023.399999999999</td><td>1011.3770678774227</td></tr><tr><td>2019</td><td>28.298668535388906</td><td>1081.9999999999995</td><td>1011.4909757681536</td></tr><tr><td>2020</td><td>28.324208860759494</td><td>5175.200000000002</td><td>1011.4429296166078</td></tr><tr><td>2021</td><td>28.583704607873074</td><td>4522.199999999998</td><td>1011.0515715593522</td></tr><tr><td>2022</td><td>28.257539682539683</td><td>8585.1</td><td>1011.0622617186241</td></tr><tr><td>2023</td><td>28.894520547945245</td><td>7273.000000000007</td><td>1011.2536377473355</td></tr><tr><td>2024</td><td>28.711806411837177</td><td>7120.50000000001</td><td>1011.2695427554031</td></tr><tr><td>2025</td><td>25.022222222222222</td><td>0.0</td><td>1012.9666666666667</td></tr></tbody></table></div>

# %% [markdown]
# Les observations météorologiques quotidiennes ont été horodatées à l'aide du temps variable. Les indicateurs annuels ont été construits en extrayant l'année de l'horodatage et en agrégeant les observations quotidiennes en moyennes annuelles (température, pression) et totaux (précipitations).

# %%
# Données météo annuelles
df_weather_annual = spark.read.table("weather_senegal_clean") \
    .withColumn("Year", F.year("time")) \
    .groupBy("Year") \
    .agg(
        F.avg("tavg").alias("avg_temperature"),
        F.sum("prcp").alias("total_precipitation"),
        F.avg("pres").alias("avg_pressure")
    )

# Données agricoles (rendements agricoles, surface emblavée, production, produits cultivés)
df_agri = (
    spark.read
    .table("annual_economic_data")
    .drop("Area", "pib_item", "pib_value", "pib_unit")
)

# %%
# On vérife les schémas des bases
df_weather_annual.printSchema()
df_agri.printSchema()
# Out:
# root
#  |-- Year: integer (nullable = true)
#  |-- avg_temperature: double (nullable = true)
#  |-- total_precipitation: double (nullable = true)
#  |-- avg_pressure: double (nullable = true)
#
# root
#  |-- Year: integer (nullable = true)
#  |-- Item: string (nullable = true)
#  |-- Element: string (nullable = true)
#  |-- Unit: string (nullable = true)
#  |-- Value: double (nullable = true)
#  |-- dep_item: string (nullable = true)
#  |-- dep_agri_value: long (nullable = true)
#  |-- dep_agri_unit: string (nullable = true)

# %%
# Puis on merge les bases 
df_merged = (
    df_agri
    .join(df_weather_annual, on="Year", how="left")
)

# %%
# Affichons la base mergée
display(df_merged.orderBy("Year"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>Item</th><th>Element</th><th>Unit</th><th>Value</th><th>dep_item</th><th>dep_agri_value</th><th>dep_agri_unit</th><th>avg_temperature</th><th>total_precipitation</th><th>avg_pressure</th></tr></thead><tbody><tr><td>2005</td><td>Millet</td><td>Production</td><td>t</td><td>608551.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Mangoes, guavas and mangosteens</td><td>Production</td><td>t</td><td>61646.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Sesame seed</td><td>Production</td><td>t</td><td>31839.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Potatoes</td><td>Yield</td><td>kg/ha</td><td>13653.6</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Other beans, green</td><td>Area harvested</td><td>ha</td><td>645.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Rice</td><td>Production</td><td>t</td><td>279080.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Carrots and turnips</td><td>Yield</td><td>kg/ha</td><td>14979.8</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Onions and shallots, dry (excluding dehydrated)</td><td>Yield</td><td>kg/ha</td><td>25000.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Seed cotton, unginned</td><td>Area harvested</td><td>ha</td><td>38254.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Oranges</td><td>Area harvested</td><td>ha</td><td>4000.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Millet</td><td>Area harvested</td><td>ha</td><td>800763.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw</td><td>Area harvested</td><td>ha</td><td>600.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Eggplants (aubergines)</td><td>Area harvested</td><td>ha</td><td>1213.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Cashew nuts, in shell</td><td>Yield</td><td>kg/ha</td><td>305.2</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Sorghum</td><td>Production</td><td>t</td><td>143989.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Oranges</td><td>Production</td><td>t</td><td>35500.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Carrots and turnips</td><td>Area harvested</td><td>ha</td><td>247.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Coc ...

# %%
# On affiche le schéma après avoir mergé
df_merged.printSchema()
# Out:
# root
#  |-- Year: integer (nullable = true)
#  |-- Item: string (nullable = true)
#  |-- Element: string (nullable = true)
#  |-- Unit: string (nullable = true)
#  |-- Value: double (nullable = true)
#  |-- dep_item: string (nullable = true)
#  |-- dep_agri_value: long (nullable = true)
#  |-- dep_agri_unit: string (nullable = true)
#  |-- avg_temperature: double (nullable = true)
#  |-- total_precipitation: double (nullable = true)
#  |-- avg_pressure: double (nullable = true)

# %%
# Sauvegarde de la base annuelle (agriculture + climat)
(
    df_merged
    .write
    .mode("overwrite")  
    .format("delta")     
    .saveAsTable("annual_agri_climate_data")
)

print(" Table Delta créée : annual_agri_climate_data")
# Out:
#  Table Delta créée : annual_agri_climate_data

# %%
# Chargeons la table sauvegardée, on visualise puis on compte le nombre d'observations
df_check = spark.read.table("annual_agri_climate_data")
df_check.printSchema()
display(df_check.limit(5))
print("Nombre total d'observations :", df_check.count())
# Out:
# root
#  |-- Year: integer (nullable = true)
#  |-- Item: string (nullable = true)
#  |-- Element: string (nullable = true)
#  |-- Unit: string (nullable = true)
#  |-- Value: double (nullable = true)
#  |-- dep_item: string (nullable = true)
#  |-- dep_agri_value: long (nullable = true)
#  |-- dep_agri_unit: string (nullable = true)
#  |-- avg_temperature: double (nullable = true)
#  |-- total_precipitation: double (nullable = true)
#  |-- avg_pressure: double (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>Item</th><th>Element</th><th>Unit</th><th>Value</th><th>dep_item</th><th>dep_agri_value</th><th>dep_agri_unit</th><th>avg_temperature</th><th>total_precipitation</th><th>avg_pressure</th></tr></thead><tbody><tr><td>2005</td><td>Bananas</td><td>Area harvested</td><td>ha</td><td>939.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Bananas</td><td>Yield</td><td>kg/ha</td><td>28026.6</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2005</td><td>Bananas</td><td>Production</td><td>t</td><td>26317.0</td><td>null</td><td>null</td><td>null</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td></tr><tr><td>2006</td><td>Bananas</td><td>Area harvested</td><td>ha</td><td>1222.0</td><td>null</td><td>null</td><td>null</td><td>28.531488203266775</td><td>3399.0999999999995</td><td>1011.2394931916094</td></tr><tr><td>2006</td><td>Bananas</td><td>Yield</td><td>kg/ha</td><td>24549.9</td><td>null</td><td>null</td><td>null</td><td>28.531488203266775</td><td>3399.0999999999995</td><td>1011.2394931916094</td></tr></tbody></table></div>
# Nombre total d'observations : 2055

# %% [markdown]
# Les ensembles de données météorologiques et agricoles ont été fusionnés en utilisant l'année comme clé commune. Les observations météorologiques quotidiennes ont été regroupées en indicateurs annuels, tandis que les indicateurs de production agricole ont été regroupés au niveau national. L'ensemble de données résultant permet d'analyser la variabilité climatique et sa relation avec les résultats de la production agricole au Sénégal sur la période 2005-2025.

# %% [markdown]
# ## Base économique annuelle : PIB + températures annuelles

# %%
# Chargeons la base économique
df_econ = spark.read.table("economics_data")

# %%
# On y crée la variable Year
df_econ_year = (
    df_econ
    .withColumn("Year", F.year(F.col("Unnamed_0")))
)

# %%
# PIB annuel
df_pib_annual = (
    df_econ_year
    .groupBy("Year")
    .agg(
        F.first("PIB_a_prix_constant").alias("pib_constant")
    )
    .orderBy("Year")
)

# %%
# On vérifie
df_pib_annual.printSchema()
display(df_pib_annual)
# Out:
# root
#  |-- Year: integer (nullable = true)
#  |-- pib_constant: double (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>pib_constant</th></tr></thead><tbody><tr><td>2005</td><td>6888.61</td></tr><tr><td>2006</td><td>7049.17</td></tr><tr><td>2007</td><td>7248.46</td></tr><tr><td>2008</td><td>7516.88</td></tr><tr><td>2009</td><td>7723.75</td></tr><tr><td>2010</td><td>7985.66</td></tr><tr><td>2011</td><td>8092.19</td></tr><tr><td>2012</td><td>8416.12</td></tr><tr><td>2013</td><td>8619.15</td></tr><tr><td>2014</td><td>9155.61</td></tr><tr><td>2015</td><td>9738.56</td></tr><tr><td>2016</td><td>10357.55</td></tr><tr><td>2017</td><td>11124.78</td></tr><tr><td>2018</td><td>11815.54</td></tr><tr><td>2019</td><td>12360.67</td></tr><tr><td>2020</td><td>12526.56</td></tr><tr><td>2021</td><td>13346.3</td></tr><tr><td>2022</td><td>13860.19</td></tr><tr><td>2023</td><td>14450.27</td></tr><tr><td>2024</td><td>15326.04</td></tr></tbody></table></div>

# %%
# On sauvegarde la base pib annuelle 
(df_pib_annual
 .write
 .mode("overwrite")
 .format("delta")
 .saveAsTable("pib_annual")
)

print("✅ Table Delta créée : pib_annual")
# Out:
# ✅ Table Delta créée : pib_annual

# %%
# On merge 
df_meteo_annuel = spark.read.table("weather_senegal_clean") \
    .withColumn("Year", F.year("time")) \
    .groupBy("Year") \
    .agg(
        F.avg("tavg").alias("avg_temperature"),
        F.sum("prcp").alias("total_precipitation"),
        F.avg("pres").alias("avg_pressure")
    )

df_pib_annuel = spark.read.table("pib_annual")
df_meteo_pib = (
    df_meteo_annuel
    .join(
        df_pib_annuel,
        on="Year",
        how="left"
    )
)

# %%
# Vérification
df_meteo_pib.printSchema()
display(df_meteo_pib.orderBy("Year").limit(10))
# Out:
# root
#  |-- Year: integer (nullable = true)
#  |-- avg_temperature: double (nullable = true)
#  |-- total_precipitation: double (nullable = true)
#  |-- avg_pressure: double (nullable = true)
#  |-- pib_constant: double (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>avg_temperature</th><th>total_precipitation</th><th>avg_pressure</th><th>pib_constant</th></tr></thead><tbody><tr><td>2005</td><td>28.71919682259484</td><td>5224.400000000006</td><td>1011.2347672084724</td><td>6888.61</td></tr><tr><td>2006</td><td>28.531488203266775</td><td>3399.0999999999995</td><td>1011.2394931916094</td><td>7049.17</td></tr><tr><td>2007</td><td>28.177815699658694</td><td>1702.0</td><td>1011.4508161488728</td><td>7248.46</td></tr><tr><td>2008</td><td>27.88793407886991</td><td>3991.7000000000007</td><td>1011.3557871285636</td><td>7516.88</td></tr><tr><td>2009</td><td>27.9764381402679</td><td>4925.600000000004</td><td>1011.1819275281549</td><td>7723.75</td></tr><tr><td>2010</td><td>28.764912280701715</td><td>5289.700000000004</td><td>1011.2049353344339</td><td>7985.66</td></tr><tr><td>2011</td><td>27.861874386653625</td><td>3783.8000000000006</td><td>1011.29236549284</td><td>8092.19</td></tr><tr><td>2012</td><td>27.986167146974044</td><td>6735.300000000003</td><td>1011.2694924187703</td><td>8416.12</td></tr><tr><td>2013</td><td>28.079271991911074</td><td>4491.799999999997</td><td>1011.2964570549655</td><td>8619.15</td></tr><tr><td>2014</td><td>27.59651545036165</td><td>3139.8000000000006</td><td>1011.414740059626</td><td>9155.61</td></tr></tbody></table></div>

# %%
# On sauvegarde la base
(df_meteo_pib
 .write
 .mode("overwrite")
 .format("delta")
 .saveAsTable("meteo_pib_annuel")
)

print(" Table Delta créée : meteo_pib_annuel")
# Out:
#  Table Delta créée : meteo_pib_annuel

# %% [markdown]
# ## Construisons la base mensuelle. Celle-ci va utiliser les données économiques mensuelle (indices des prix...)

# %%
# On va d'abord créer la base annuelle. Pour cela, on va chargée nos données météorologiques qu'on va merger aux données économiques traitées dans le notebook 05. data_clean_economic
df_weather = spark.read.table("weather_senegal_clean")

df_weather.printSchema()
display(df_weather.limit(5))
# Out:
# root
#  |-- region: string (nullable = true)
#  |-- time: timestamp (nullable = true)
#  |-- tavg: double (nullable = true)
#  |-- tmin: double (nullable = true)
#  |-- tmax: double (nullable = true)
#  |-- prcp: double (nullable = true)
#  |-- wspd: double (nullable = true)
#  |-- pres: double (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>time</th><th>tavg</th><th>tmin</th><th>tmax</th><th>prcp</th><th>wspd</th><th>pres</th></tr></thead><tbody><tr><td>Dakar</td><td>2005-01-01T00:00:00.000Z</td><td>22.6</td><td>18.5</td><td>28.0</td><td>0.0</td><td>16.4</td><td>1012.2986111111122</td></tr><tr><td>Dakar</td><td>2005-01-02T00:00:00.000Z</td><td>21.5</td><td>18.8</td><td>24.0</td><td>0.0</td><td>17.0</td><td>1012.2986111111122</td></tr><tr><td>Dakar</td><td>2005-01-05T00:00:00.000Z</td><td>20.1</td><td>18.0</td><td>23.0</td><td>0.0</td><td>16.2</td><td>1012.2986111111122</td></tr><tr><td>Dakar</td><td>2005-01-08T00:00:00.000Z</td><td>22.1</td><td>19.9</td><td>25.0</td><td>0.0</td><td>21.2</td><td>1012.2986111111122</td></tr><tr><td>Dakar</td><td>2005-01-09T00:00:00.000Z</td><td>21.6</td><td>19.0</td><td>25.0</td><td>0.0</td><td>19.0</td><td>1012.2986111111122</td></tr></tbody></table></div>

# %%
# On crée les variables year et month
df_weather = df_weather.withColumn(
    "year", F.year(F.col("time"))
).withColumn(
    "month", F.month(F.col("time"))
)

# %%
# Agrégeons les données en données mensuelles
df_weather_monthly = (
    df_weather
    .groupBy("region", "year", "month")
    .agg(
        F.avg("tavg").alias("avg_tavg"),
        F.avg("tmin").alias("avg_tmin"),
        F.avg("tmax").alias("avg_tmax"),
        F.sum("prcp").alias("total_prcp"),
        F.avg("wspd").alias("avg_wspd"),
        F.avg("pres").alias("avg_pres")
    )
    .orderBy("region", "year", "month")
)
# Affichons les données
display(df_weather_monthly.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>year</th><th>month</th><th>avg_tavg</th><th>avg_tmin</th><th>avg_tmax</th><th>total_prcp</th><th>avg_wspd</th><th>avg_pres</th></tr></thead><tbody><tr><td>Dakar</td><td>2005</td><td>1</td><td>21.788888888888895</td><td>18.994444444444444</td><td>26.29444444444444</td><td>0.0</td><td>16.400000000000002</td><td>1012.7439814814817</td></tr><tr><td>Dakar</td><td>2005</td><td>2</td><td>20.009523809523806</td><td>18.009523809523813</td><td>23.928571428571427</td><td>4.0</td><td>21.500000000000004</td><td>1013.1857142857143</td></tr><tr><td>Dakar</td><td>2005</td><td>3</td><td>21.892</td><td>19.067999999999998</td><td>26.128</td><td>0.0</td><td>19.22</td><td>1012.1519999999999</td></tr><tr><td>Dakar</td><td>2005</td><td>4</td><td>22.477272727272727</td><td>20.10454545454546</td><td>26.027272727272724</td><td>0.0</td><td>20.609090909090906</td><td>1012.2986111111128</td></tr><tr><td>Dakar</td><td>2005</td><td>5</td><td>25.357142857142858</td><td>23.285714285714285</td><td>28.81428571428572</td><td>0.0</td><td>12.721220784033454</td><td>1011.5046957671957</td></tr></tbody></table></div>

# %%
# On compte le nombre d'observations pour vérification
df_weather_monthly.count()
# Out:
# 2048

# %% [markdown]
# 2048 car on va de janvier 2005 à janvier 2025

# %%
# Chargeons la base économique
df_econ = spark.read.table("economics_data")
df_econ.show(5)
df_econ.printSchema()
df_econ.count()
# Out:
# +----------+--------------------------------------------------------------+------------------------------------+---------------------------------+-------------------------------------------+----------------------------------------+--------------------------------------+-----------------------------------------------------------------+-------------------------------------------------------------------+------------------------------------------------------------+-------------------+
# | Unnamed_0|Indice_de_la_production_industrielle_des_produits_alimentaires|Indice_de_la_production_industrielle|Indice_des_prix_a_la_consommation|Indice_des_prix_de_la_fonction_alimentation|Indice_des_prix_de_la_fonction_Transport|Indice_des_prix_de_la_fonction_Loisirs|Taux_d_inflation_en_glissement_annuel_de_la_fonction_alimentation|Taux_d_inflation_en_glissement_annuel_de_la_fonction_alimentation_1|Taux_d_inflation_en_glissement_annuel_de_la_fonction_Loisirs|PIB_a_prix_constant|
# +----------+--------------------------------------------------------------+------------------------------------+---------------------------------+-------------------------------------------+----------------------------------------+--------------------------------------+-----------------------------------------------------------------+-------------------------------------------------------------------+------------------------------------------------------------+-------------------+
# |2005-01-01|                                                        116.37|                              100.76|                             83.2|                                       74.1|                                    74.4|                                 101.0|                                                              2.0|                                                                2.0|                                                       -0.62|            6888.61|
# |2005-02-01|                                                        133.22|                              108.16|                             83.3|                                       74.8|                                    74.1|                                 101.0|                                                             2.01|                                                               2.01|                                                       -0.74|            6888.61|
# |2005-03-01|                                                        186.66|                              142.86|                             83.0|                                       74.0|                                    74.5|                                 101.0|                                                             1.25|                                                               1.25|                                                       -0.65|            6888.61|
# |2005-04-01|                                                        167.58|                              129.56|                             82.7|                                       73.5|                                    74.6|                                 101.2|                                                              2.1|                                                                2.1|                                                       -0.52|            6888.61|
# |2005-05-01|                                                        156.56|                              125.51|                             82.9|                                       73.7|                                    75.4|                                 101.2|                                                             2.79|                                                               2.79|                                                       -0.51|            6888.61|
# +----------+--------------------------------------------------------------+------------------------------------+---------------------------------+-------------------------------------------+----------------------------------------+--------------------------------------+-----------------------------------------------------------------+-------------------------------------------------------------------+------------------------------------------------------------+-------------------+
# only showing top 5 rows
# root
#  |-- Unnamed_0: date (nullable = true)
#  |-- Indice_de_la_production_industrielle_des_produits_alimentaires: double (nullable = true)
#  |-- Indice_de_la_production_industrielle: double (nullable = true)
#  |-- Indice_des_prix_a_la_consommation: double (nullable = true)
#  |-- Indice_des_prix_de_la_fonction_alimentation: double (nullable = true)
#  |-- Indice_des_prix_de_la_fonction_Transport: double (nullable = true)
#  |-- Indice_des_prix_de_la_fonction_Loisirs: double (nullable = true)
#  |-- Taux_d_inflation_en_glissement_annuel_de_la_fonction_alimentation: double (nullable = true)
#  |-- Taux_d_inflation_en_glissement_annuel_de_la_fonction_alimentation_1: double (nullable = true)
#  |-- Taux_d_inflation_en_glissement_annuel_de_la_fonction_Loisirs: double (nullable = true)
#  |-- PIB_a_prix_constant: double (nullable = true)
# 240

# %%
# On renomme les variables pour avoir des noms plus court 
df_econ_renamed = (
    df_econ
    .withColumnRenamed("Unnamed_0", "date")
    .withColumnRenamed("Indice_de_la_production_industrielle_des_produits_alimentaires", "ipi_alim")
    .withColumnRenamed("Indice_de_la_production_industrielle", "ipi_total")
    .withColumnRenamed("Indice_des_prix_a_la_consommation", "cpi")
    .withColumnRenamed("Indice_des_prix_de_la_fonction_alimentation", "cpi_food")
    .withColumnRenamed("Indice_des_prix_de_la_fonction_Transport", "cpi_transport")
    .withColumnRenamed("Indice_des_prix_de_la_fonction_Loisirs", "cpi_entertain")
    .withColumnRenamed("Taux_d_inflation_en_glissement_annuel_de_la_fonction_alimentation", "infl_food")
    .withColumnRenamed("Taux_d_inflation_en_glissement_annuel_de_la_fonction_alimentation_1", "infl_food_lag1")
    .withColumnRenamed("Taux_d_inflation_en_glissement_annuel_de_la_fonction_Loisirs", "infl_entertain")
    .withColumnRenamed("PIB_a_prix_constant", "pib_constant")
)

df_econ_renamed.printSchema()
# Out:
# root
#  |-- date: date (nullable = true)
#  |-- ipi_alim: double (nullable = true)
#  |-- ipi_total: double (nullable = true)
#  |-- cpi: double (nullable = true)
#  |-- cpi_food: double (nullable = true)
#  |-- cpi_transport: double (nullable = true)
#  |-- cpi_entertain: double (nullable = true)
#  |-- infl_food: double (nullable = true)
#  |-- infl_food_lag1: double (nullable = true)
#  |-- infl_entertain: double (nullable = true)
#  |-- pib_constant: double (nullable = true)

# %%
# On crée la variable mois
df_econ = df_econ_renamed.withColumn("date", F.to_timestamp("date"))

df_econ = (
    df_econ_renamed
    .withColumn("Year", F.year("date"))
    .withColumn("Month", F.month("date"))
)

# %%
# On visualise la base
df_econ.select("date", "Year", "Month").show(20)
# Out:
# +----------+----+-----+
# |      date|Year|Month|
# +----------+----+-----+
# |2005-01-01|2005|    1|
# |2005-02-01|2005|    2|
# |2005-03-01|2005|    3|
# |2005-04-01|2005|    4|
# |2005-05-01|2005|    5|
# |2005-06-01|2005|    6|
# |2005-07-01|2005|    7|
# |2005-08-01|2005|    8|
# |2005-09-01|2005|    9|
# |2005-10-01|2005|   10|
# |2005-11-01|2005|   11|
# |2005-12-01|2005|   12|
# |2006-01-01|2006|    1|
# |2006-02-01|2006|    2|
# |2006-03-01|2006|    3|
# |2006-04-01|2006|    4|
# |2006-05-01|2006|    5|
# |2006-06-01|2006|    6|
# |2006-07-01|2006|    7|
# |2006-08-01|2006|    8|
# +----------+----+-----+
# only showing top 20 rows

# %%
# On merge les données économiques aux données météorologiques mensuelles.
df_merged = (
    df_econ
    .join(
        df_weather_monthly,
        on=["Year", "Month"],
        how="left"
    )
)

# %%
# On vérifie la fusion
df_merged.show(20)
df_merged.printSchema()
# Out:
# +----+-----+----------+--------+---------+----+--------+-------------+-------------+---------+--------------+--------------+------------+-----------+------------------+------------------+------------------+-----------------+------------------+------------------+
# |Year|Month|      date|ipi_alim|ipi_total| cpi|cpi_food|cpi_transport|cpi_entertain|infl_food|infl_food_lag1|infl_entertain|pib_constant|     region|          avg_tavg|          avg_tmin|          avg_tmax|       total_prcp|          avg_wspd|          avg_pres|
# +----+-----+----------+--------+---------+----+--------+-------------+-------------+---------+--------------+--------------+------------+-----------+------------------+------------------+------------------+-----------------+------------------+------------------+
# |2005|    1|2005-01-01|  116.37|   100.76|83.2|    74.1|         74.4|        101.0|      2.0|           2.0|         -0.62|     6888.61|Tambacounda| 26.94545454545455|19.336363636363636| 34.14090909090909|              0.0|10.798035660320354|1010.7027090144799|
# |2005|    2|2005-02-01|  133.22|   108.16|83.3|    74.8|         74.1|        101.0|     2.01|          2.01|         -0.74|     6888.61| Ziguinchor|27.692307692307697|              21.5| 37.07692307692307|              0.0| 7.915902891434773|1011.9252761257436|
# |2005|    3|2005-03-01|  186.66|   142.86|83.0|    74.0|         74.5|        101.0|     1.25|          1.25|         -0.65|     6888.61|   Kédougou|32.221428571428575|23.717857142857152| 39.81785714285716|              0.0| 8.938233264320239|1010.6020041465089|
# |2005|    4|2005-04-01|  167.58|   129.56|82.7|    73.5|         74.6|        101.2|      2.1|           2.1|         -0.52|     6888.61|   Kédougou| 33.88799999999999|26.831999999999994| 41.02800000000001|              0.0| 8.938233264320239|1010.6020041465089|
# |2005|    5|2005-05-01|  156.56|   125.51|82.9|    73.7|         75.4|        101.2|     2.79|          2.79|         -0.51|     6888.61|Saint-Louis| 26.15238095238095|22.557142857142853|30.680952380952384|              0.0|12.199503448275864|1012.0026280018124|
# |2005|    6|2005-06-01|  148.96|   123.54|83.6|    75.2|         75.8|        100.7|     5.14|          5.14|         -0.79|     6888.61|      Dakar|            27.112|             24.98|30.328000000000007|              5.1|            13.352|1012.6480000000001|
# |2005|    7|2005-07-01|  101.01|   108.16|84.9|    77.9|         76.3|        100.7|      4.8|           4.8|         -0.53|     6888.61|      Matam| 31.65238095238096|25.995238095238093|              37.5|75.39999999999999|  9.61646423751687|1010.5124913733595|
# |2005|    8|2005-08-01|  123.67|   110.38|85.9|    79.5|         76.9|        100.8|     4.63|          4.63|         -0.37|     6888.61|      Kolda|27.894736842105264|23.636842105263156| 32.77894736842106|            118.1| 7.617667356797794|1010.3424033149179|
# |2005|    9|2005-09-01|  105.84|   100.23|86.9|    81.3|         78.6|        100.8|     7.28|          7.28|         -0.45|     6888.61|Tambacounda|27.766666666666662|22.295238095238094| 32.85714285714286|            170.2|10.798035660320354|1010.7027090144799|
# |2005|   10|2005-10-01|   87.18|     93.2|88.2|    83.1|         83.8|        100.9|     8.82|          8.82|         -0.46|     6888.61|      Dakar|27.863333333333333|             25.37|31.526666666666674|             43.0|             10.01|1012.2933333333334|
# |2005|   11|2005-11-01|  109.22|     99.5|85.8|    77.9|         83.6|        100.7|     3.69|          3.69|         -0.63|     6888.61|      Matam|29.292307692307688|21.496153846153845| 38.76538461538461|              0.0| 9.616464237516873|1010.5124913733596|
# |2005|   12|2005-12-01|  128.02|   101.25|84.9|    76.4|         82.4|        100.7|     1.84|          1.84|         -0.48|     6888.61|      Matam|27.984615384615385| 20.81153846153846|36.434615384615384|              0.0| 9.616464237516873|1010.5124913733596|
# |2006|    1|2006-01-01|  109.04|   109.85|84.8|    75.4|         82.3|        102.1|     1.74|          1.74|          1.05|     7049.17| Ziguinchor|24.999999999999996|18.400000000000002| 32.42857142857143|              0.0| 7.915902891434776|1011.9252761257438|
# |2006|    2|2006-02-01|  118.82|   100.67|85.1|    76.3|         82.9|        103.6|     2.07|          2.07|          2.63|     7049.17|      Kolda|28.841666666666665|18.958333333333332| 38.31666666666667|              0.0| 7.617667356797795| 1010.342403314918|
# |2006|    3|2006-03-01|  143.43|   100.18|85.6|    77.2|         83.2|        102.0|     4.21|          4.21|          0.99|     7049.17|      Matam| 31.24827586206897|22.337931034482757| 41.01379310344828|              0.0| 9.616464237516874|1010.5124913733596|
# |2006|    4|2006-04-01|   151.3|    93.45|85.3|    76.5|         83.6|        102.1|     4.09|          4.09|          0.88|     7049.17|      Kolda|  32.7095238095238|23.409523809523808|  41.1047619047619|              0.0| 7.617667356797794|1010.3424033149178|
# |2006|    5|2006-05-01|  156.41|   104.26|84.5|    74.6|         84.1|        102.0|     1.19|          1.19|          0.82|     7049.17| Ziguinchor|          28.88125|          22.61875|38.162499999999994|              0.0| 7.915902891434772|1011.9252761257435|
# |2006|    6|2006-06-01|  143.19|    95.79|84.9|    75.0|         84.1|        102.0|    -0.17|         -0.17|          1.33|     7049.17|   Diourbel|30.649999999999995|             23.98|             38.09|             57.1| 9.512413793103438|1011.2890883977896|
# |2006|    7|2006-07-01|  112.77|    82.29|86.0|    77.0|         84.5|        102.0|    -1.09|         -1.09|           1.3|     7049.17|    Kaolack|29.413636363636364|25.968181818181822| 35.39090909090909|             33.5|11.837954701441298|1011.4194616977243|
# |2006|    8|2006-08-01|  131.61|     86.9|87.0|    79.0|         85.0|        102.0|    -0.67|         -0.67|          1.18|     7049.17|Tambacounda|28.422727272727276|23.259090909090908|33.040909090909096|             65.5|10.798035660320354|1010.7027090144799|
# +----+-----+----------+--------+---------+----+--------+-------------+-------------+---------+--------------+--------------+------------+-----------+------------------+------------------+------------------+-----------------+------------------+------------------+
# only showing top 20 rows
# root
#  |-- Year: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- ipi_alim: double (nullable = true)
#  |-- ipi_total: double (nullable = true)
#  |-- cpi: double (nullable = true)
#  |-- cpi_food: double (nullable = true)
#  |-- cpi_transport: double (nullable = true)
#  |-- cpi_entertain: double (nullable = true)
#  |-- infl_food: double (nullable = true)
#  |-- infl_food_lag1: double (nullable = true)
#  |-- infl_entertain: double (nullable = true)
#  |-- pib_constant: double (nullable = true)
#  |-- region: string (nullable = true)
#  |-- avg_tavg: double (nullable = true)
#  |-- avg_tmin: double (nullable = true)
#  |-- avg_tmax: double (nullable = true)
#  |-- total_prcp: double (nullable = true)
#  |-- avg_wspd: double (nullable = true)
#  |-- avg_pres: double (nullable = true)

# %%
# On compte le nombre d'éléments
df_merged.count()
# Out:
# 2039

# %% [markdown]
# La base finale va de janvier 2005 à décembre 2024

# %%
# Sauvegardons la base mensuelle 
(df_merged
 .write
 .mode("overwrite")
 .format("delta")
 .saveAsTable("mensual_data")
)
print("Table Delta créée : mensual_data")
# Out:
# ✅ Table Delta créée : mensual_data

# %% [markdown]
# ### Les bases mensuelles et annuelles seront utilisées dans les les notebook d'analyses et de visualisation
